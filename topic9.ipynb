# %% [markdown]
# Sorting and Filtering Data
#
# Filtering Data
# Definition: Selecting specific rows that match a condition.
# Examples:
# Get all rows where price > 100
# Get all rows where category is "Electronics"
# Get rows where age is between 18 and 25
#
#
# Sorting Data
# Definition: Rearranging the rows based on the values in one or more columns.
# Examples:
# Sort products by price (low to high)
# Sort students by marks in descending order
# Sort sales by region and date

# %%
# ============================== Sorting & Filtering Data in Pandas ==============================

# --- Sorting Data ---
# Sort by values in ascending order
# df.sort_values(by='column')

# Sort by values in descending order
# df.sort_values(by='column', ascending=False)

# Sort by multiple columns
# df.sort_values(by=['col1', 'col2'])

# Sort by index (ascending)
# df.sort_index()

# Sort by index (descending)
# df.sort_index(ascending=False)

# --- Filtering Data (Row Selection) ---
# Filter rows where column is greater than 100
# df[df['column'] > 100]

# Filter where column is equal to a specific value
# df[df['column'] == 'value']

# Filter where column value is in a list
# df[df['column'].isin(['A', 'B'])]

# Filter rows where column contains specific text
# df[df['column'].str.contains('text')]

# --- Filtering with Multiple Conditions ---
# AND condition
# df[(df['col1'] > 50) & (df['col2'] < 100)]

# OR condition
# df[(df['col1'] == 'A') | (df['col2'] == 'B')]

# --- Using the Query Method ---
# Query with a single condition
# df.query("column > 100")

# Query with complex condition
# df.query("col1 == 'A' and col2 < 50")

# --- Using loc & iloc ---
# Label-based filtering with loc
# df.loc[df['column'] == 'value']

# Index-based filtering with iloc (first 5 rows)
# df.iloc[0:5]

# --- Drop Duplicates for Unique Rows ---
# Drop all duplicate rows
# df.drop_duplicates()

# Drop duplicates based on specific column
# df.drop_duplicates(subset='column')

# --- Filtering with Between, Not, and Negation ---
# Filter values between 10 and 20 (inclusive)
# df[df['column'].between(10, 20)]

# Filter rows where column NOT in list
# df[~df['column'].isin(['A', 'B'])]

# %%
import pandas as pd

# %%
df = pd.read_excel("Coffee.xlsx")
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 0              5  Lower Manhattan          32        3.00              Coffee
# 1              5  Lower Manhattan          57        3.10                 Tea
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 3              5  Lower Manhattan          22        2.00              Coffee
# 4              5  Lower Manhattan          57        3.10                 Tea
# ...          ...              ...         ...         ...                 ...
# 149111         8   Hell's Kitchen          44        2.50                 Tea
# 149112         8   Hell's Kitchen          49        3.00                 Tea
# 149113         8   Hell's Kitchen          45        3.00                 Tea
# 149114         8   Hell's Kitchen          40        3.75              Coffee
# 149115         8   Hell's Kitchen          64        0.80            Flavours
#
#                  product_type               product_detail
# 0       Gourmet brewed coffee                  Ethiopia Rg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2               Hot chocolate            Dark chocolate Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...                       ...                          ...
# 149111      Brewed herbal tea                Peppermint Rg
# 149112       Brewed Black tea         English Breakfast Lg
# 149113      Brewed herbal tea                Peppermint Lg
# 149114       Barista Espresso                   Cappuccino
# 149115          Regular syrup               Hazelnut syrup
#
# [149116 rows x 11 columns]

# %%
df.sort_values(by='unit_price')                  
# Sort by values in ascending order
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 50890            50997       2023-03-25         16:44:01                2
# 50919            51026       2023-03-25         17:17:09                1
# 50957            51064       2023-03-25         18:15:23                1
# 107713          107967       2023-05-26         07:32:42                1
# 107721          107975       2023-05-26         07:39:02                1
# ...                ...              ...              ...              ...
# 23697            23754       2023-02-12         09:02:14                1
# 64674            64844       2023-04-12         15:16:12                1
# 103464          103718       2023-05-22         08:20:52                1
# 48232            48339       2023-03-21         20:52:55                1
# 71825            71995       2023-04-20         16:56:39                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 50890          5  Lower Manhattan          65         0.8         Flavours
# 50919          5  Lower Manhattan          65         0.8         Flavours
# 50957          5  Lower Manhattan          65         0.8         Flavours
# 107713         5  Lower Manhattan          64         0.8         Flavours
# 107721         5  Lower Manhattan          64         0.8         Flavours
# ...          ...              ...         ...         ...              ...
# 23697          8   Hell's Kitchen           8        45.0     Coffee beans
# 64674          5  Lower Manhattan           8        45.0     Coffee beans
# 103464         5  Lower Manhattan           8        45.0     Coffee beans
# 48232          8   Hell's Kitchen           8        45.0     Coffee beans
# 71825          3          Astoria           8        45.0     Coffee beans
#
#             product_type            product_detail
# 50890   Sugar free syrup  Sugar Free Vanilla syrup
# 50919   Sugar free syrup  Sugar Free Vanilla syrup
# 50957   Sugar free syrup  Sugar Free Vanilla syrup
# 107713     Regular syrup            Hazelnut syrup
# 107721     Regular syrup            Hazelnut syrup
# ...                  ...                       ...
# 23697      Premium Beans                 Civet Cat
# 64674      Premium Beans                 Civet Cat
# 103464     Premium Beans                 Civet Cat
# 48232      Premium Beans                 Civet Cat
# 71825      Premium Beans                 Civet Cat
#
# [149116 rows x 11 columns]

# %%
df.sort_values(by='unit_price', ascending=False) 
# Sort by values in descending order
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 103464          103718       2023-05-22         08:20:52                1
# 13832            13862       2023-01-25         08:49:41                1
# 73990            74160       2023-04-23         11:23:14                1
# 148573          148914       2023-06-30         10:25:26                1
# 103238          103492       2023-05-21         20:52:55                1
# ...                ...              ...              ...              ...
# 127611          127948       2023-06-12         19:11:38                1
# 53675            53784       2023-03-30         06:42:35                1
# 53691            53800       2023-03-30         07:07:32                2
# 98348            98602       2023-05-17         12:50:44                1
# 98150            98404       2023-05-17         10:20:46                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 103464         5  Lower Manhattan           8        45.0     Coffee beans
# 13832          8   Hell's Kitchen           8        45.0     Coffee beans
# 73990          8   Hell's Kitchen           8        45.0     Coffee beans
# 148573         8   Hell's Kitchen           8        45.0     Coffee beans
# 103238         8   Hell's Kitchen           8        45.0     Coffee beans
# ...          ...              ...         ...         ...              ...
# 127611         8   Hell's Kitchen          63         0.8         Flavours
# 53675          5  Lower Manhattan          63         0.8         Flavours
# 53691          8   Hell's Kitchen          63         0.8         Flavours
# 98348          5  Lower Manhattan          63         0.8         Flavours
# 98150          8   Hell's Kitchen          63         0.8         Flavours
#
#          product_type product_detail
# 103464  Premium Beans      Civet Cat
# 13832   Premium Beans      Civet Cat
# 73990   Premium Beans      Civet Cat
# 148573  Premium Beans      Civet Cat
# 103238  Premium Beans      Civet Cat
# ...               ...            ...
# 127611  Regular syrup   Carmel syrup
# 53675   Regular syrup   Carmel syrup
# 53691   Regular syrup   Carmel syrup
# 98348   Regular syrup   Carmel syrup
# 98150   Regular syrup   Carmel syrup
#
# [149116 rows x 11 columns]

# %%
df.sort_values(by=['unit_price', 'transaction_id'])   
# Sort by multiple columns
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3254              3284       2023-01-07         06:27:23                2
# 3291              3321       2023-01-07         07:44:17                1
# 3318              3348       2023-01-07         08:09:37                1
# 3325              3355       2023-01-07         08:18:07                1
# 3331              3361       2023-01-07         08:20:30                1
# ...                ...              ...              ...              ...
# 144743          145080       2023-06-27         07:49:34                1
# 145411          145748       2023-06-27         12:12:41                1
# 148573          148914       2023-06-30         10:25:26                1
# 148702          149043       2023-06-30         11:18:31                8
# 148784          149125       2023-06-30         13:03:56                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 3254           5  Lower Manhattan          64         0.8         Flavours
# 3291           5  Lower Manhattan          63         0.8         Flavours
# 3318           8   Hell's Kitchen          65         0.8         Flavours
# 3325           5  Lower Manhattan          65         0.8         Flavours
# 3331           5  Lower Manhattan          64         0.8         Flavours
# ...          ...              ...         ...         ...              ...
# 144743         5  Lower Manhattan           8        45.0     Coffee beans
# 145411         5  Lower Manhattan           8        45.0     Coffee beans
# 148573         8   Hell's Kitchen           8        45.0     Coffee beans
# 148702         8   Hell's Kitchen           8        45.0     Coffee beans
# 148784         5  Lower Manhattan           8        45.0     Coffee beans
#
#             product_type            product_detail
# 3254       Regular syrup            Hazelnut syrup
# 3291       Regular syrup              Carmel syrup
# 3318    Sugar free syrup  Sugar Free Vanilla syrup
# 3325    Sugar free syrup  Sugar Free Vanilla syrup
# 3331       Regular syrup            Hazelnut syrup
# ...                  ...                       ...
# 144743     Premium Beans                 Civet Cat
# 145411     Premium Beans                 Civet Cat
# 148573     Premium Beans                 Civet Cat
# 148702     Premium Beans                 Civet Cat
# 148784     Premium Beans                 Civet Cat
#
# [149116 rows x 11 columns]

# %%
df.sort_index()                              
# Sort by index (ascending)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 0              5  Lower Manhattan          32        3.00              Coffee
# 1              5  Lower Manhattan          57        3.10                 Tea
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 3              5  Lower Manhattan          22        2.00              Coffee
# 4              5  Lower Manhattan          57        3.10                 Tea
# ...          ...              ...         ...         ...                 ...
# 149111         8   Hell's Kitchen          44        2.50                 Tea
# 149112         8   Hell's Kitchen          49        3.00                 Tea
# 149113         8   Hell's Kitchen          45        3.00                 Tea
# 149114         8   Hell's Kitchen          40        3.75              Coffee
# 149115         8   Hell's Kitchen          64        0.80            Flavours
#
#                  product_type               product_detail
# 0       Gourmet brewed coffee                  Ethiopia Rg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2               Hot chocolate            Dark chocolate Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...                       ...                          ...
# 149111      Brewed herbal tea                Peppermint Rg
# 149112       Brewed Black tea         English Breakfast Lg
# 149113      Brewed herbal tea                Peppermint Lg
# 149114       Barista Espresso                   Cappuccino
# 149115          Regular syrup               Hazelnut syrup
#
# [149116 rows x 11 columns]

# %%
df.sort_index(ascending=False)               
# Sort by index (descending)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 149115          149456       2023-06-30         20:57:19                2
# 149114          149455       2023-06-30         20:57:19                1
# 149113          149454       2023-06-30         20:31:34                1
# 149112          149453       2023-06-30         20:25:10                2
# 149111          149452       2023-06-30         20:18:41                2
# ...                ...              ...              ...              ...
# 4                    5       2023-01-01         07:22:41                2
# 3                    4       2023-01-01         07:20:24                1
# 2                    3       2023-01-01         07:14:04                2
# 1                    2       2023-01-01         07:08:56                2
# 0                    1       2023-01-01         07:06:11                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 149115         8   Hell's Kitchen          64        0.80            Flavours
# 149114         8   Hell's Kitchen          40        3.75              Coffee
# 149113         8   Hell's Kitchen          45        3.00                 Tea
# 149112         8   Hell's Kitchen          49        3.00                 Tea
# 149111         8   Hell's Kitchen          44        2.50                 Tea
# ...          ...              ...         ...         ...                 ...
# 4              5  Lower Manhattan          57        3.10                 Tea
# 3              5  Lower Manhattan          22        2.00              Coffee
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 1              5  Lower Manhattan          57        3.10                 Tea
# 0              5  Lower Manhattan          32        3.00              Coffee
#
#                  product_type               product_detail
# 149115          Regular syrup               Hazelnut syrup
# 149114       Barista Espresso                   Cappuccino
# 149113      Brewed herbal tea                Peppermint Lg
# 149112       Brewed Black tea         English Breakfast Lg
# 149111      Brewed herbal tea                Peppermint Rg
# ...                       ...                          ...
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm
# 2               Hot chocolate            Dark chocolate Lg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 0       Gourmet brewed coffee                  Ethiopia Rg
#
# [149116 rows x 11 columns]

# %%
df[df['unit_price'] > 10]                       
# Filter rows based on condition
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3293              3323       2023-01-07         07:44:17                1
# 3296              3326       2023-01-07         07:45:15                1
# 3302              3332       2023-01-07         07:50:42                1
# 3408              3438       2023-01-07         09:05:19                1
# 3447              3477       2023-01-07         09:42:52                1
# ...                ...              ...              ...              ...
# 148739          149080       2023-06-30         11:42:44                1
# 148784          149125       2023-06-30         13:03:56                1
# 148927          149268       2023-06-30         15:59:13                1
# 149064          149405       2023-06-30         18:49:29                1
# 149089          149430       2023-06-30         19:32:46                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 3293           5  Lower Manhattan           6       21.00     Coffee beans
# 3296           5  Lower Manhattan           9       28.00     Coffee beans
# 3302           5  Lower Manhattan           9       28.00     Coffee beans
# 3408           5  Lower Manhattan           9       28.00     Coffee beans
# 3447           5  Lower Manhattan           7       19.75     Coffee beans
# ...          ...              ...         ...         ...              ...
# 148739         5  Lower Manhattan           2       18.00     Coffee beans
# 148784         5  Lower Manhattan           8       45.00     Coffee beans
# 148927         3          Astoria           7       19.75     Coffee beans
# 149064         3          Astoria           3       14.75     Coffee beans
# 149089         8   Hell's Kitchen           1       18.00     Coffee beans
#
#              product_type            product_detail
# 3293        Gourmet Beans                  Ethiopia
# 3296        Organic Beans       Organic Decaf Blend
# 3302        Organic Beans       Organic Decaf Blend
# 3408        Organic Beans       Organic Decaf Blend
# 3447        Premium Beans     Jamacian Coffee River
# ...                   ...                       ...
# 148739  House blend Beans  Our Old Time Diner Blend
# 148784      Premium Beans                 Civet Cat
# 148927      Premium Beans     Jamacian Coffee River
# 149064     Espresso Beans            Espresso Roast
# 149089      Organic Beans       Brazilian - Organic
#
# [2636 rows x 11 columns]

# %%
df['product_category'].unique
# Out:
# <bound method Series.unique of 0                     Coffee
# 1                        Tea
# 2         Drinking Chocolate
# 3                     Coffee
# 4                        Tea
#                  ...
# 149111                   Tea
# 149112                   Tea
# 149113                   Tea
# 149114                Coffee
# 149115              Flavours
# Name: product_category, Length: 149116, dtype: object>

# %%
df[df['product_type'] == 'Brewed Chai tea']                  
# Filter where column equals a value
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 1                    2       2023-01-01         07:08:56                2
# 4                    5       2023-01-01         07:22:41                2
# 10                  11       2023-01-01         07:43:05                1
# 13                  14       2023-01-01         07:48:19                1
# 21                  22       2023-01-01         08:24:26                2
# ...                ...              ...              ...              ...
# 149054          149395       2023-06-30         18:38:35                2
# 149078          149419       2023-06-30         19:15:30                1
# 149099          149440       2023-06-30         19:46:02                2
# 149107          149448       2023-06-30         19:57:49                2
# 149109          149450       2023-06-30         20:08:38                2
#
#         store_id   store_location  product_id  unit_price product_category  \
# 1              5  Lower Manhattan          57        3.10              Tea
# 4              5  Lower Manhattan          57        3.10              Tea
# 10             5  Lower Manhattan          56        2.55              Tea
# 13             5  Lower Manhattan          57        3.10              Tea
# 21             5  Lower Manhattan          56        2.55              Tea
# ...          ...              ...         ...         ...              ...
# 149054         3          Astoria          54        2.50              Tea
# 149078         3          Astoria          53        3.00              Tea
# 149099         8   Hell's Kitchen          55        4.00              Tea
# 149107         3          Astoria          54        2.50              Tea
# 149109         8   Hell's Kitchen          55        4.00              Tea
#
#            product_type             product_detail
# 1       Brewed Chai tea   Spicy Eye Opener Chai Lg
# 4       Brewed Chai tea   Spicy Eye Opener Chai Lg
# 10      Brewed Chai tea   Spicy Eye Opener Chai Rg
# 13      Brewed Chai tea   Spicy Eye Opener Chai Lg
# 21      Brewed Chai tea   Spicy Eye Opener Chai Rg
# ...                 ...                        ...
# 149054  Brewed Chai tea    Morning Sunrise Chai Rg
# 149078  Brewed Chai tea  Traditional Blend Chai Lg
# 149099  Brewed Chai tea    Morning Sunrise Chai Lg
# 149107  Brewed Chai tea    Morning Sunrise Chai Rg
# 149109  Brewed Chai tea    Morning Sunrise Chai Lg
#
# [17183 rows x 11 columns]

# %%
df[df['product_category'].isin(['Tea', 'Flavours'])]            
# Filter where column is in a list
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 1                    2       2023-01-01         07:08:56                2
# 4                    5       2023-01-01         07:22:41                2
# 10                  11       2023-01-01         07:43:05                1
# 12                  13       2023-01-01         07:45:51                1
# 13                  14       2023-01-01         07:48:19                1
# ...                ...              ...              ...              ...
# 149110          149451       2023-06-30         20:16:31                2
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price product_category  \
# 1              5  Lower Manhattan          57        3.10              Tea
# 4              5  Lower Manhattan          57        3.10              Tea
# 10             5  Lower Manhattan          56        2.55              Tea
# 12             5  Lower Manhattan          51        3.00              Tea
# 13             5  Lower Manhattan          57        3.10              Tea
# ...          ...              ...         ...         ...              ...
# 149110         5  Lower Manhattan          42        2.50              Tea
# 149111         8   Hell's Kitchen          44        2.50              Tea
# 149112         8   Hell's Kitchen          49        3.00              Tea
# 149113         8   Hell's Kitchen          45        3.00              Tea
# 149115         8   Hell's Kitchen          64        0.80         Flavours
#
#              product_type            product_detail
# 1         Brewed Chai tea  Spicy Eye Opener Chai Lg
# 4         Brewed Chai tea  Spicy Eye Opener Chai Lg
# 10        Brewed Chai tea  Spicy Eye Opener Chai Rg
# 12       Brewed Black tea              Earl Grey Lg
# 13        Brewed Chai tea  Spicy Eye Opener Chai Lg
# ...                   ...                       ...
# 149110  Brewed herbal tea            Lemon Grass Rg
# 149111  Brewed herbal tea             Peppermint Rg
# 149112   Brewed Black tea      English Breakfast Lg
# 149113  Brewed herbal tea             Peppermint Lg
# 149115      Regular syrup            Hazelnut syrup
#
# [52239 rows x 11 columns]

# %%
df[df['product_type'].str.contains('Brewed Chai tea')]        
# Filter rows containing text
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 1                    2       2023-01-01         07:08:56                2
# 4                    5       2023-01-01         07:22:41                2
# 10                  11       2023-01-01         07:43:05                1
# 13                  14       2023-01-01         07:48:19                1
# 21                  22       2023-01-01         08:24:26                2
# ...                ...              ...              ...              ...
# 149054          149395       2023-06-30         18:38:35                2
# 149078          149419       2023-06-30         19:15:30                1
# 149099          149440       2023-06-30         19:46:02                2
# 149107          149448       2023-06-30         19:57:49                2
# 149109          149450       2023-06-30         20:08:38                2
#
#         store_id   store_location  product_id  unit_price product_category  \
# 1              5  Lower Manhattan          57        3.10              Tea
# 4              5  Lower Manhattan          57        3.10              Tea
# 10             5  Lower Manhattan          56        2.55              Tea
# 13             5  Lower Manhattan          57        3.10              Tea
# 21             5  Lower Manhattan          56        2.55              Tea
# ...          ...              ...         ...         ...              ...
# 149054         3          Astoria          54        2.50              Tea
# 149078         3          Astoria          53        3.00              Tea
# 149099         8   Hell's Kitchen          55        4.00              Tea
# 149107         3          Astoria          54        2.50              Tea
# 149109         8   Hell's Kitchen          55        4.00              Tea
#
#            product_type             product_detail
# 1       Brewed Chai tea   Spicy Eye Opener Chai Lg
# 4       Brewed Chai tea   Spicy Eye Opener Chai Lg
# 10      Brewed Chai tea   Spicy Eye Opener Chai Rg
# 13      Brewed Chai tea   Spicy Eye Opener Chai Lg
# 21      Brewed Chai tea   Spicy Eye Opener Chai Rg
# ...                 ...                        ...
# 149054  Brewed Chai tea    Morning Sunrise Chai Rg
# 149078  Brewed Chai tea  Traditional Blend Chai Lg
# 149099  Brewed Chai tea    Morning Sunrise Chai Lg
# 149107  Brewed Chai tea    Morning Sunrise Chai Rg
# 149109  Brewed Chai tea    Morning Sunrise Chai Lg
#
# [17183 rows x 11 columns]

# %%
df[(df['transaction_qty'] > 2) & (df['unit_price'] < 10)]
# AND condition
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3842              3872       2023-01-08         07:37:12                3
# 3977              4007       2023-01-08         09:34:26                3
# 4088              4118       2023-01-08         10:59:55                3
# 4163              4193       2023-01-08         12:58:32                4
# 4352              4382       2023-01-08         19:32:15                4
# ...                ...              ...              ...              ...
# 148904          149245       2023-06-30         15:32:47                3
# 148943          149284       2023-06-30         16:22:45                3
# 148944          149285       2023-06-30         16:23:49                3
# 148988          149329       2023-06-30         17:31:23                3
# 149012          149353       2023-06-30         17:59:31                3
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 3842           5  Lower Manhattan          63        0.80            Flavours
# 3977           5  Lower Manhattan          63        0.80            Flavours
# 4088           5  Lower Manhattan          65        0.80            Flavours
# 4163           5  Lower Manhattan          65        0.80            Flavours
# 4352           5  Lower Manhattan          64        0.80            Flavours
# ...          ...              ...         ...         ...                 ...
# 148904         5  Lower Manhattan          58        3.50  Drinking Chocolate
# 148943         5  Lower Manhattan          23        2.50              Coffee
# 148944         5  Lower Manhattan          25        2.20              Coffee
# 148988         5  Lower Manhattan          44        2.50                 Tea
# 149012         5  Lower Manhattan          39        4.25              Coffee
#
#                  product_type               product_detail
# 3842            Regular syrup                 Carmel syrup
# 3977            Regular syrup                 Carmel syrup
# 4088         Sugar free syrup     Sugar Free Vanilla syrup
# 4163         Sugar free syrup     Sugar Free Vanilla syrup
# 4352            Regular syrup               Hazelnut syrup
# ...                       ...                          ...
# 148904          Hot chocolate            Dark chocolate Rg
# 148943            Drip coffee  Our Old Time Diner Blend Rg
# 148944  Organic brewed coffee                 Brazilian Sm
# 148988      Brewed herbal tea                Peppermint Rg
# 149012       Barista Espresso                     Latte Rg
#
# [3300 rows x 11 columns]

# %%
df[(df['transaction_qty'] >6) | (df['unit_price'] > 15)]# OR condition
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3293              3323       2023-01-07         07:44:17                1
# 3296              3326       2023-01-07         07:45:15                1
# 3302              3332       2023-01-07         07:50:42                1
# 3408              3438       2023-01-07         09:05:19                1
# 3447              3477       2023-01-07         09:42:52                1
# ...                ...              ...              ...              ...
# 148702          149043       2023-06-30         11:18:31                8
# 148739          149080       2023-06-30         11:42:44                1
# 148784          149125       2023-06-30         13:03:56                1
# 148927          149268       2023-06-30         15:59:13                1
# 149089          149430       2023-06-30         19:32:46                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 3293           5  Lower Manhattan           6       21.00     Coffee beans
# 3296           5  Lower Manhattan           9       28.00     Coffee beans
# 3302           5  Lower Manhattan           9       28.00     Coffee beans
# 3408           5  Lower Manhattan           9       28.00     Coffee beans
# 3447           5  Lower Manhattan           7       19.75     Coffee beans
# ...          ...              ...         ...         ...              ...
# 148702         8   Hell's Kitchen           8       45.00     Coffee beans
# 148739         5  Lower Manhattan           2       18.00     Coffee beans
# 148784         5  Lower Manhattan           8       45.00     Coffee beans
# 148927         3          Astoria           7       19.75     Coffee beans
# 149089         8   Hell's Kitchen           1       18.00     Coffee beans
#
#              product_type            product_detail
# 3293        Gourmet Beans                  Ethiopia
# 3296        Organic Beans       Organic Decaf Blend
# 3302        Organic Beans       Organic Decaf Blend
# 3408        Organic Beans       Organic Decaf Blend
# 3447        Premium Beans     Jamacian Coffee River
# ...                   ...                       ...
# 148702      Premium Beans                 Civet Cat
# 148739  House blend Beans  Our Old Time Diner Blend
# 148784      Premium Beans                 Civet Cat
# 148927      Premium Beans     Jamacian Coffee River
# 149089      Organic Beans       Brazilian - Organic
#
# [1532 rows x 11 columns]

# %%
df[df['unit_price'].between(25, 40)]             
# Values between 10 and 20
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 3296              3326       2023-01-07         07:45:15                1
# 3302              3332       2023-01-07         07:50:42                1
# 3408              3438       2023-01-07         09:05:19                1
# 4598              4628       2023-01-09         09:42:16                1
# 5596              5626       2023-01-11         07:20:48                1
# ...                ...              ...              ...              ...
# 143861          144198       2023-06-26         09:25:39                1
# 144254          144591       2023-06-26         13:44:30                1
# 144519          144856       2023-06-26         17:33:41                1
# 144680          145017       2023-06-27         07:09:41                1
# 145618          145955       2023-06-27         15:19:35                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# 3296           5  Lower Manhattan           9        28.0     Coffee beans
# 3302           5  Lower Manhattan           9        28.0     Coffee beans
# 3408           5  Lower Manhattan           9        28.0     Coffee beans
# 4598           5  Lower Manhattan          81        28.0          Branded
# 5596           8   Hell's Kitchen          81        28.0          Branded
# ...          ...              ...         ...         ...              ...
# 143861         5  Lower Manhattan          81        28.0          Branded
# 144254         5  Lower Manhattan          81        28.0          Branded
# 144519         5  Lower Manhattan          81        28.0          Branded
# 144680         5  Lower Manhattan          81        28.0          Branded
# 145618         5  Lower Manhattan          81        28.0          Branded
#
#          product_type           product_detail
# 3296    Organic Beans      Organic Decaf Blend
# 3302    Organic Beans      Organic Decaf Blend
# 3408    Organic Beans      Organic Decaf Blend
# 4598         Clothing  I Need My Bean! T-shirt
# 5596         Clothing  I Need My Bean! T-shirt
# ...               ...                      ...
# 143861       Clothing  I Need My Bean! T-shirt
# 144254       Clothing  I Need My Bean! T-shirt
# 144519       Clothing  I Need My Bean! T-shirt
# 144680       Clothing  I Need My Bean! T-shirt
# 145618       Clothing  I Need My Bean! T-shirt
#
# [233 rows x 11 columns]
