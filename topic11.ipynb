# %%
# ==========================
# 📌 Merging and Joining Data
# ==========================

# --- Using pd.merge() ---

# Merge on a common column (default inner join)
# pd.merge(df1, df2, on='key')

# Merge on different column names
# pd.merge(df1, df2, left_on='key1', right_on='key2')

# Inner join (only matching rows)
# pd.merge(df1, df2, on='key', how='inner')

# Left join (all rows from df1, matching from df2)
# pd.merge(df1, df2, on='key', how='left')

# Right join (all rows from df2, matching from df1)
# pd.merge(df1, df2, on='key', how='right')

# Outer join (all rows from both, with NaN where no match)
# pd.merge(df1, df2, on='key', how='outer')

# Cross join (cartesian product of two datasets)
# pd.merge(df1, df2, on='key', how='cross')

# --- Using DataFrame.join() ---

# Join on index (requires setting index beforehand)
# df1.set_index('key').join(df2.set_index('key'))

# --- Concatenation ---

# Concatenate DataFrames along rows (axis=0)
# pd.concat([df1, df2])

# Concatenate DataFrames along columns (axis=1)
# pd.concat([df1, df2], axis=1)

# Concatenate and reindex the result
# pd.concat([df1, df2], ignore_index=True)

# %%
import pandas as pd

# Load main dataset
df1 = pd.read_excel("Coffee.xlsx")

# %%
df1.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2          Hot chocolate            Dark chocolate Lg
# 3            Drip coffee  Our Old Time Diner Blend Sm
# 4        Brewed Chai tea     Spicy Eye Opener Chai Lg

# %%
# Sample product info
df2 = pd.DataFrame({
    'product_id': [32, 57, 59, 99],
    'product_name': ['Ethiopia Rg', 'Spicy Chai Lg', 'Dark Chocolate Lg', 'Unknown'],
    'supplier': ['AromaCo', 'TeaFarm', 'ChocoMelt', 'Unknown']
})

# %%
#  Basic merge
merged_df = pd.merge(df1, df2, on='product_id')
merged_df
# Out:
#       transaction_id transaction_date transaction_time  transaction_qty  \
# 0                  1       2023-01-01         07:06:11                2
# 1                  2       2023-01-01         07:08:56                2
# 2                  3       2023-01-01         07:14:04                2
# 3                  5       2023-01-01         07:22:41                2
# 4                 14       2023-01-01         07:48:19                1
# ...              ...              ...              ...              ...
# 8841          149401       2023-06-30         18:44:49                1
# 8842          149403       2023-06-30         18:49:29                2
# 8843          149408       2023-06-30         18:52:33                1
# 8844          149413       2023-06-30         19:04:35                1
# 8845          149416       2023-06-30         19:10:03                2
#
#       store_id   store_location  product_id  unit_price    product_category  \
# 0            5  Lower Manhattan          32         3.0              Coffee
# 1            5  Lower Manhattan          57         3.1                 Tea
# 2            5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3            5  Lower Manhattan          57         3.1                 Tea
# 4            5  Lower Manhattan          57         3.1                 Tea
# ...        ...              ...         ...         ...                 ...
# 8841         3          Astoria          59         4.5  Drinking Chocolate
# 8842         3          Astoria          32         3.0              Coffee
# 8843         3          Astoria          32         3.0              Coffee
# 8844         8   Hell's Kitchen          32         3.0              Coffee
# 8845         3          Astoria          59         4.5  Drinking Chocolate
#
#                product_type            product_detail       product_name  \
# 0     Gourmet brewed coffee               Ethiopia Rg        Ethiopia Rg
# 1           Brewed Chai tea  Spicy Eye Opener Chai Lg      Spicy Chai Lg
# 2             Hot chocolate         Dark chocolate Lg  Dark Chocolate Lg
# 3           Brewed Chai tea  Spicy Eye Opener Chai Lg      Spicy Chai Lg
# 4           Brewed Chai tea  Spicy Eye Opener Chai Lg      Spicy Chai Lg
# ...                     ...                       ...                ...
# 8841          Hot chocolate         Dark chocolate Lg  Dark Chocolate Lg
# 8842  Gourmet brewed coffee               Ethiopia Rg        Ethiopia Rg
# 8843  Gourmet brewed coffee               Ethiopia Rg        Ethiopia Rg
# 8844  Gourmet brewed coffee               Ethiopia Rg        Ethiopia Rg
# 8845          Hot chocolate         Dark chocolate Lg  Dark Chocolate Lg
#
#        supplier
# 0       AromaCo
# 1       TeaFarm
# 2     ChocoMelt
# 3       TeaFarm
# 4       TeaFarm
# ...         ...
# 8841  ChocoMelt
# 8842    AromaCo
# 8843    AromaCo
# 8844    AromaCo
# 8845  ChocoMelt
#
# [8846 rows x 13 columns]

# %%
#  Left join (all coffee transactions, even if no matching product)
left_joined = pd.merge(df1, df2, on='product_id', how='left')
left_joined
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 0              5  Lower Manhattan          32        3.00              Coffee
# 1              5  Lower Manhattan          57        3.10                 Tea
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 3              5  Lower Manhattan          22        2.00              Coffee
# 4              5  Lower Manhattan          57        3.10                 Tea
# ...          ...              ...         ...         ...                 ...
# 149111         8   Hell's Kitchen          44        2.50                 Tea
# 149112         8   Hell's Kitchen          49        3.00                 Tea
# 149113         8   Hell's Kitchen          45        3.00                 Tea
# 149114         8   Hell's Kitchen          40        3.75              Coffee
# 149115         8   Hell's Kitchen          64        0.80            Flavours
#
#                  product_type               product_detail       product_name  \
# 0       Gourmet brewed coffee                  Ethiopia Rg        Ethiopia Rg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg      Spicy Chai Lg
# 2               Hot chocolate            Dark chocolate Lg  Dark Chocolate Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm                NaN
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg      Spicy Chai Lg
# ...                       ...                          ...                ...
# 149111      Brewed herbal tea                Peppermint Rg                NaN
# 149112       Brewed Black tea         English Breakfast Lg                NaN
# 149113      Brewed herbal tea                Peppermint Lg                NaN
# 149114       Barista Espresso                   Cappuccino                NaN
# 149115          Regular syrup               Hazelnut syrup                NaN
#
#          supplier
# 0         AromaCo
# 1         TeaFarm
# 2       ChocoMelt
# 3             NaN
# 4         TeaFarm
# ...           ...
# 149111        NaN
# 149112        NaN
# 149113        NaN
# 149114        NaN
# 149115        NaN
#
# [149116 rows x 13 columns]

# %%
#  Right join (all products even if no transaction)
right_joined = pd.merge(df1, df2, on='product_id', how='right')
right_joined
# Out:
#       transaction_id transaction_date transaction_time  transaction_qty  \
# 0                1.0       2023-01-01         07:06:11              2.0
# 1               51.0       2023-01-01         09:14:41              1.0
# 2               80.0       2023-01-01         10:00:39              2.0
# 3               84.0       2023-01-01         10:16:30              2.0
# 4              199.0       2023-01-01         12:50:28              2.0
# ...              ...              ...              ...              ...
# 8842        149320.0       2023-06-30         17:22:44              1.0
# 8843        149387.0       2023-06-30         18:30:02              1.0
# 8844        149401.0       2023-06-30         18:44:49              1.0
# 8845        149416.0       2023-06-30         19:10:03              2.0
# 8846             NaN              NaT              NaN              NaN
#
#       store_id   store_location  product_id  unit_price    product_category  \
# 0          5.0  Lower Manhattan          32         3.0              Coffee
# 1          8.0   Hell's Kitchen          32         3.0              Coffee
# 2          8.0   Hell's Kitchen          32         3.0              Coffee
# 3          5.0  Lower Manhattan          32         3.0              Coffee
# 4          3.0          Astoria          32         3.0              Coffee
# ...        ...              ...         ...         ...                 ...
# 8842       8.0   Hell's Kitchen          59         4.5  Drinking Chocolate
# 8843       5.0  Lower Manhattan          59         4.5  Drinking Chocolate
# 8844       3.0          Astoria          59         4.5  Drinking Chocolate
# 8845       3.0          Astoria          59         4.5  Drinking Chocolate
# 8846       NaN              NaN          99         NaN                 NaN
#
#                product_type     product_detail       product_name   supplier
# 0     Gourmet brewed coffee        Ethiopia Rg        Ethiopia Rg    AromaCo
# 1     Gourmet brewed coffee        Ethiopia Rg        Ethiopia Rg    AromaCo
# 2     Gourmet brewed coffee        Ethiopia Rg        Ethiopia Rg    AromaCo
# 3     Gourmet brewed coffee        Ethiopia Rg        Ethiopia Rg    AromaCo
# 4     Gourmet brewed coffee        Ethiopia Rg        Ethiopia Rg    AromaCo
# ...                     ...                ...                ...        ...
# 8842          Hot chocolate  Dark chocolate Lg  Dark Chocolate Lg  ChocoMelt
# 8843          Hot chocolate  Dark chocolate Lg  Dark Chocolate Lg  ChocoMelt
# 8844          Hot chocolate  Dark chocolate Lg  Dark Chocolate Lg  ChocoMelt
# 8845          Hot chocolate  Dark chocolate Lg  Dark Chocolate Lg  ChocoMelt
# 8846                    NaN                NaN            Unknown    Unknown
#
# [8847 rows x 13 columns]

# %%
# Outer join (all records from both)
outer_joined = pd.merge(df1, df2, on='product_id', how='outer', indicator=True)
outer_joined
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0               3481.0       2023-01-07         09:44:57              1.0
# 1               3866.0       2023-01-08         07:30:17              1.0
# 2               3971.0       2023-01-08         09:13:06              2.0
# 3               4329.0       2023-01-08         17:48:46              1.0
# 4               4573.0       2023-01-09         08:57:44              1.0
# ...                ...              ...              ...              ...
# 149112        149040.0       2023-06-30         11:18:31              1.0
# 149113        149297.0       2023-06-30         16:33:19              1.0
# 149114        149319.0       2023-06-30         17:20:32              2.0
# 149115        149370.0       2023-06-30         18:10:40              1.0
# 149116             NaN              NaT              NaN              NaN
#
#         store_id   store_location  product_id  unit_price product_category  \
# 0            8.0   Hell's Kitchen           1        18.0     Coffee beans
# 1            5.0  Lower Manhattan           1        18.0     Coffee beans
# 2            5.0  Lower Manhattan           1        18.0     Coffee beans
# 3            3.0          Astoria           1        18.0     Coffee beans
# 4            5.0  Lower Manhattan           1        18.0     Coffee beans
# ...          ...              ...         ...         ...              ...
# 149112       8.0   Hell's Kitchen          87         2.1           Coffee
# 149113       5.0  Lower Manhattan          87         3.0           Coffee
# 149114       8.0   Hell's Kitchen          87         3.0           Coffee
# 149115       8.0   Hell's Kitchen          87         3.0           Coffee
# 149116       NaN              NaN          99         NaN              NaN
#
#             product_type        product_detail product_name supplier  \
# 0          Organic Beans   Brazilian - Organic          NaN      NaN
# 1          Organic Beans   Brazilian - Organic          NaN      NaN
# 2          Organic Beans   Brazilian - Organic          NaN      NaN
# 3          Organic Beans   Brazilian - Organic          NaN      NaN
# 4          Organic Beans   Brazilian - Organic          NaN      NaN
# ...                  ...                   ...          ...      ...
# 149112  Barista Espresso  Ouro Brasileiro shot          NaN      NaN
# 149113  Barista Espresso  Ouro Brasileiro shot          NaN      NaN
# 149114  Barista Espresso  Ouro Brasileiro shot          NaN      NaN
# 149115  Barista Espresso  Ouro Brasileiro shot          NaN      NaN
# 149116               NaN                   NaN      Unknown  Unknown
#
#             _merge
# 0        left_only
# 1        left_only
# 2        left_only
# 3        left_only
# 4        left_only
# ...            ...
# 149112   left_only
# 149113   left_only
# 149114   left_only
# 149115   left_only
# 149116  right_only
#
# [149117 rows x 14 columns]

# %%
# Join using index (if product_id is index)
df1_indexed = df1.set_index("product_id")
df2_indexed = df2.set_index("product_id")

joined_df = df1_indexed.join(df2_indexed, how="left")
joined_df
# Out:
#             transaction_id transaction_date transaction_time  transaction_qty  \
# product_id
# 32                       1       2023-01-01         07:06:11                2
# 57                       2       2023-01-01         07:08:56                2
# 59                       3       2023-01-01         07:14:04                2
# 22                       4       2023-01-01         07:20:24                1
# 57                       5       2023-01-01         07:22:41                2
# ...                    ...              ...              ...              ...
# 44                  149452       2023-06-30         20:18:41                2
# 49                  149453       2023-06-30         20:25:10                2
# 45                  149454       2023-06-30         20:31:34                1
# 40                  149455       2023-06-30         20:57:19                1
# 64                  149456       2023-06-30         20:57:19                2
#
#             store_id   store_location  unit_price    product_category  \
# product_id
# 32                 5  Lower Manhattan        3.00              Coffee
# 57                 5  Lower Manhattan        3.10                 Tea
# 59                 5  Lower Manhattan        4.50  Drinking Chocolate
# 22                 5  Lower Manhattan        2.00              Coffee
# 57                 5  Lower Manhattan        3.10                 Tea
# ...              ...              ...         ...                 ...
# 44                 8   Hell's Kitchen        2.50                 Tea
# 49                 8   Hell's Kitchen        3.00                 Tea
# 45                 8   Hell's Kitchen        3.00                 Tea
# 40                 8   Hell's Kitchen        3.75              Coffee
# 64                 8   Hell's Kitchen        0.80            Flavours
#
#                      product_type               product_detail  \
# product_id
# 32          Gourmet brewed coffee                  Ethiopia Rg
# 57                Brewed Chai tea     Spicy Eye Opener Chai Lg
# 59                  Hot chocolate            Dark chocolate Lg
# 22                    Drip coffee  Our Old Time Diner Blend Sm
# 57                Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...                           ...                          ...
# 44              Brewed herbal tea                Peppermint Rg
# 49               Brewed Black tea         English Breakfast Lg
# 45              Brewed herbal tea                Peppermint Lg
# 40               Barista Espresso                   Cappuccino
# 64                  Regular syrup               Hazelnut syrup
#
#                  product_name   supplier
# product_id
# 32                Ethiopia Rg    AromaCo
# 57              Spicy Chai Lg    TeaFarm
# 59          Dark Chocolate Lg  ChocoMelt
# 22                        NaN        NaN
# 57              Spicy Chai Lg    TeaFarm
# ...                       ...        ...
# 44                        NaN        NaN
# 49                        NaN        NaN
# 45                        NaN        NaN
# 40                        NaN        NaN
# 64                        NaN        NaN
#
# [149116 rows x 12 columns]

# %%
# Concatenation
pd.concat([df1, df1])                          # Duplicate rows vertically
pd.concat([df1, df2], axis=1)                  # Combine side-by-side (column-wise)
pd.concat([df1, df1], ignore_index=True)       # Reset index after row-wise concat
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 298227          149452       2023-06-30         20:18:41                2
# 298228          149453       2023-06-30         20:25:10                2
# 298229          149454       2023-06-30         20:31:34                1
# 298230          149455       2023-06-30         20:57:19                1
# 298231          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 0              5  Lower Manhattan          32        3.00              Coffee
# 1              5  Lower Manhattan          57        3.10                 Tea
# 2              5  Lower Manhattan          59        4.50  Drinking Chocolate
# 3              5  Lower Manhattan          22        2.00              Coffee
# 4              5  Lower Manhattan          57        3.10                 Tea
# ...          ...              ...         ...         ...                 ...
# 298227         8   Hell's Kitchen          44        2.50                 Tea
# 298228         8   Hell's Kitchen          49        3.00                 Tea
# 298229         8   Hell's Kitchen          45        3.00                 Tea
# 298230         8   Hell's Kitchen          40        3.75              Coffee
# 298231         8   Hell's Kitchen          64        0.80            Flavours
#
#                  product_type               product_detail
# 0       Gourmet brewed coffee                  Ethiopia Rg
# 1             Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2               Hot chocolate            Dark chocolate Lg
# 3                 Drip coffee  Our Old Time Diner Blend Sm
# 4             Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...                       ...                          ...
# 298227      Brewed herbal tea                Peppermint Rg
# 298228       Brewed Black tea         English Breakfast Lg
# 298229      Brewed herbal tea                Peppermint Lg
# 298230       Barista Espresso                   Cappuccino
# 298231          Regular syrup               Hazelnut syrup
#
# [298232 rows x 11 columns]
