# %% [markdown]
# Cleaning data
# Cleaning data in pandas means fixing or removing incorrect, missing, or inconsistent data to make the dataset ready for analysis

# %%
import pandas as pd

# %%
# ============================== Pandas Data Cleaning & Preprocessing ==============================

# --- Missing Data ---
# | Operation                         | Description                                 |
# |----------------------------------|---------------------------------------------|
# | df.isnull()                      | Check for missing values                    |
# | df.notnull()                     | Check for non-missing values                |
# | df.dropna()                      | Drop rows with missing values               |
# | df.dropna(axis=1)                | Drop columns with missing values            |
# | df.fillna(value)                 | Fill missing values with a specified value  |
# | df.fillna(method='ffill')       | Forward fill (last valid value)             |
# | df.fillna(method='bfill')       | Backward fill (next valid value)            |
# | df.interpolate()                | Interpolate missing values                  |

# --- Duplicate Data ---
# | df.duplicated()                 | Check for duplicate rows                    |
# | df.drop_duplicates()           | Drop duplicate rows                         |

# --- Value Replacement ---
# | df.replace('old', 'new')        | Replace a specific value                    |
# | df.replace([1, 2], [3, 4])      | Replace multiple values                     |
# | df.replace({1: 'one'})          | Replace using a dictionary                  |

# --- Renaming & Reindexing ---
# | df.rename(columns={"old": "new"}) | Rename columns                            |
# | df.set_index('col')             | Set a specific column as index             |
# | df.reset_index(drop=True)       | Reset index to default                     |

# --- String Cleanup ---
# | df['col'].str.strip()           | Remove leading/trailing whitespace          |
# | df['col'].str.lower()           | Convert strings to lowercase                |
# | df['col'].str.upper()           | Convert strings to uppercase                |
# | df['col'].str.replace(',', '')  | Remove commas or specific characters        |
# | df['col'].str.contains('txt')   | Filter rows containing a pattern            |

# --- Type Conversion ---
# | df.astype({'col': 'int'})       | Convert to specific type                    |
# | pd.to_numeric(df['col'])        | Convert string numbers to numeric           |
# | pd.to_datetime(df['date_col'])  | Convert string to datetime                  |

# --- Filtering & Removing ---
# | df[df['col'] != 'val']          | Remove rows with specific value             |
# | df.query('col > 100')           | Filter rows using a condition               |
# | df[df['col'].isin(['A','B'])]   | Keep rows with values in list               |

# --- Column Cleanup ---
# | df.drop(['col1'], axis=1)       | Drop column(s)                              |
# | df.columns.str.strip()          | Strip whitespace from column names          |
#---------------------------------------------------------------------------------|


# Axis Used: 
# axis=0 👉 Refers to rows
# axis=1 👉 Refers to columns

# %%
exceldata = pd.read_excel("Coffee.xlsx")

# %%
exceldata.head(10)
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
# 5               6       2023-01-01         07:22:41                1
# 6               7       2023-01-01         07:25:49                1
# 7               8       2023-01-01         07:33:34                2
# 8               9       2023-01-01         07:39:13                1
# 9              10       2023-01-01         07:39:34                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32        3.00              Coffee
# ...

# %%
exceldata.shape
# Rows 149116 and Columns 11
# Out:
# (149116, 11)

# %%
exceldata.isnull()
# Out:
#         transaction_id  transaction_date  transaction_time  transaction_qty  \
# 0                False             False             False            False
# 1                False             False             False            False
# 2                False             False             False            False
# 3                False             False             False            False
# 4                False             False             False            False
# ...                ...               ...               ...              ...
# 149111           False             False             False            False
# 149112           False             False             False            False
# 149113           False             False             False            False
# 149114           False             False             False            False
# 149115           False             False             False            False
#
# ...

# %%
exceldata.notnull()
# Out:
#         transaction_id  transaction_date  transaction_time  transaction_qty  \
# 0                 True              True              True             True
# 1                 True              True              True             True
# 2                 True              True              True             True
# 3                 True              True              True             True
# 4                 True              True              True             True
# ...                ...               ...               ...              ...
# 149111            True              True              True             True
# 149112            True              True              True             True
# 149113            True              True              True             True
# 149114            True              True              True             True
# 149115            True              True              True             True
#
# ...

# %%
#  the total number of null (missing) values in each column
exceldata.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
exceldata['product_category'].unique()
# Out:
# array(['Coffee', 'Tea', 'Drinking Chocolate', 'Bakery', 'Flavours',
#        'Loose Tea', 'Coffee beans', 'Packaged Chocolate', 'Branded'],
#       dtype=object)

# %%
# Drop columns with any missing values
exceldata.dropna(axis=1)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Fill missing values with a fixed value
exceldata.fillna(0)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Fill missing values forward (previous row value)
exceldata.fillna(method='ffill')
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_17976\4134703691.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   exceldata.fillna(method='ffill')
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# ...

# %%
# Fill missing values backward (next row value)
exceldata.fillna(method='bfill')
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_17976\2601351712.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   exceldata.fillna(method='bfill')
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# ...

# %%
# Interpolate missing values
exceldata.interpolate()
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_17976\3827129587.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   exceldata.interpolate()
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# ...

# %%
# Check for duplicate rows
exceldata.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149111    False
# 149112    False
# 149113    False
# 149114    False
# 149115    False
# Length: 149116, dtype: bool

# %%
# Check for total duplicate rows
exceldata.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Replace specific value
exceldata.replace('Lower Manhattan', 'Downtown NYC')
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price    product_category  \
# ...

# %%
# Replace multiple values using a list
exceldata.replace([3.00, 3.10], [3.5, 3.6])
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                  1.0       2023-01-01         07:06:11              2.0
# 1                  2.0       2023-01-01         07:08:56              2.0
# 2                  3.5       2023-01-01         07:14:04              2.0
# 3                  4.0       2023-01-01         07:20:24              1.0
# 4                  5.0       2023-01-01         07:22:41              2.0
# ...                ...              ...              ...              ...
# 149111        149452.0       2023-06-30         20:18:41              2.0
# 149112        149453.0       2023-06-30         20:25:10              2.0
# 149113        149454.0       2023-06-30         20:31:34              1.0
# 149114        149455.0       2023-06-30         20:57:19              1.0
# 149115        149456.0       2023-06-30         20:57:19              2.0
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Replace using dictionary
exceldata.replace({'Gourmet brewed coffee': 'Premium Coffee'})
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Rename column
exceldata.rename(columns={"product_detail": "product_description"})
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Set index to a specific column
exceldata.set_index('transaction_id')
# Out:
#                transaction_date transaction_time  transaction_qty  store_id  \
# transaction_id
# 1                    2023-01-01         07:06:11                2         5
# 2                    2023-01-01         07:08:56                2         5
# 3                    2023-01-01         07:14:04                2         5
# 4                    2023-01-01         07:20:24                1         5
# 5                    2023-01-01         07:22:41                2         5
# ...                         ...              ...              ...       ...
# 149452               2023-06-30         20:18:41                2         8
# 149453               2023-06-30         20:25:10                2         8
# 149454               2023-06-30         20:31:34                1         8
# 149455               2023-06-30         20:57:19                1         8
# 149456               2023-06-30         20:57:19                2         8
#
# ...

# %%
# Reset index to default integers
exceldata.reset_index(drop=True)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# Remove leading and trailing whitespace
exceldata['store_location'].str.strip()
# Out:
# 0         Lower Manhattan
# 1         Lower Manhattan
# 2         Lower Manhattan
# 3         Lower Manhattan
# 4         Lower Manhattan
#                ...
# 149111     Hell's Kitchen
# 149112     Hell's Kitchen
# 149113     Hell's Kitchen
# 149114     Hell's Kitchen
# 149115     Hell's Kitchen
# Name: store_location, Length: 149116, dtype: object

# %%
exceldata['product_category'].str.lower()
# Out:
# 0                     coffee
# 1                        tea
# 2         drinking chocolate
# 3                     coffee
# 4                        tea
#                  ...
# 149111                   tea
# 149112                   tea
# 149113                   tea
# 149114                coffee
# 149115              flavours
# Name: product_category, Length: 149116, dtype: object

# %%
exceldata['product_category'].str.upper()
# Out:
# 0                     COFFEE
# 1                        TEA
# 2         DRINKING CHOCOLATE
# 3                     COFFEE
# 4                        TEA
#                  ...
# 149111                   TEA
# 149112                   TEA
# 149113                   TEA
# 149114                COFFEE
# 149115              FLAVOURS
# Name: product_category, Length: 149116, dtype: object

# %%
# Remove characters
exceldata['product_detail'].str.replace(',', '', regex=True)
# Out:
# 0                         Ethiopia Rg
# 1            Spicy Eye Opener Chai Lg
# 2                   Dark chocolate Lg
# 3         Our Old Time Diner Blend Sm
# 4            Spicy Eye Opener Chai Lg
#                      ...
# 149111                  Peppermint Rg
# 149112           English Breakfast Lg
# 149113                  Peppermint Lg
# 149114                     Cappuccino
# 149115                 Hazelnut syrup
# Name: product_detail, Length: 149116, dtype: object

# %%
# Check for pattern matching
exceldata['product_detail'].str.contains('Chai')
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 149111    False
# 149112    False
# 149113    False
# 149114    False
# 149115    False
# Name: product_detail, Length: 149116, dtype: bool

# %%
# Convert to integers
exceldata['transaction_qty'].astype(int)
# Out:
# 0         2
# 1         2
# 2         2
# 3         1
# 4         2
#          ..
# 149111    2
# 149112    2
# 149113    1
# 149114    1
# 149115    2
# Name: transaction_qty, Length: 149116, dtype: int64

# %%
pd.to_datetime(exceldata['transaction_date'])
# Out:
# 0        2023-01-01
# 1        2023-01-01
# 2        2023-01-01
# 3        2023-01-01
# 4        2023-01-01
#             ...
# 149111   2023-06-30
# 149112   2023-06-30
# 149113   2023-06-30
# 149114   2023-06-30
# 149115   2023-06-30
# Name: transaction_date, Length: 149116, dtype: datetime64[ns]

# %%
pd.to_numeric(exceldata['unit_price'])
# Out:
# 0         3.00
# 1         3.10
# 2         4.50
# 3         2.00
# 4         3.10
#           ...
# 149111    2.50
# 149112    3.00
# 149113    3.00
# 149114    3.75
# 149115    0.80
# Name: unit_price, Length: 149116, dtype: float64

# %%
# Filter out rows with a specific value
exceldata[exceldata['store_location'] != 'Lower Manhattan']
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 17                  18       2023-01-01         08:00:18                1
# 18                  19       2023-01-01         08:00:39                2
# 19                  20       2023-01-01         08:11:45                1
# 20                  21       2023-01-01         08:17:27                2
# 23                  24       2023-01-01         08:29:38                1
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price    product_category  \
# ...

# %%
exceldata.query('transaction_qty >= 2')
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 4                    5       2023-01-01         07:22:41                2
# 7                    8       2023-01-01         07:33:34                2
# ...                ...              ...              ...              ...
# 149109          149450       2023-06-30         20:08:38                2
# 149110          149451       2023-06-30         20:16:31                2
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
exceldata[exceldata['product_category'].isin(['Coffee', 'Tea'])]
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# 6                    7       2023-01-01         07:25:49                1
# ...                ...              ...              ...              ...
# 149110          149451       2023-06-30         20:16:31                2
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
#
#         store_id   store_location  product_id  unit_price product_category  \
# ...

# %%
# # Drop specific columns
exceldata.drop(['product_id', 'product_type'], axis=1)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  unit_price    product_category  \
# ...

# %%
exceldata.drop('store_id', axis=1)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#          store_location  product_id  unit_price    product_category  \
# ...

# %%
# Remove leading/trailing spaces from all column names
exceldata.columns =exceldata.columns.str.strip()
exceldata
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...
