# %% [markdown]
# Selecting index data means accessing specific rows in a DataFrame using row labels (with .loc[]) or row positions (with .iloc[]).

# %%
import pandas as pd

# %%
datacsv = pd.read_csv("laptops_dataset.csv")

# %%
datacsv.head()
# Out:
#                                         product_name  overall_rating  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
#
#   no_ratings no_reviews  rating             title  \
# 0     15,210        900       5  Perfect product!
# 1     15,210        900       5         Fabulous!
# 2     15,210        900       5         Fabulous!
# 3     15,210        900       4        Delightful
# 4     15,210        900       5           Awesome
#
#                                               review
# 0  Loved it, it's my first MacBook that I earned ...
# 1  Battery lasted longer than my first relationsh...
# 2  Such a great deal.. very happy with the perfor...
# 3  Awesome build quality and very good display, b...
# 4  When i ordered and came to know about seller r...

# %%
# df['column']: Select a single column.
datacsv['review']
# Out:
# 0        Loved it, it's my first MacBook that I earned ...
# 1        Battery lasted longer than my first relationsh...
# 2        Such a great deal.. very happy with the perfor...
# 3        Awesome build quality and very good display, b...
# 4        When i ordered and came to know about seller r...
#                                ...
# 24108    MSI Laptop is high performance and the best. c...
# 24109                   Excellent performance best laptop.
# 24110    Decent battery life. Exceptional build quality...
# 24111    The product does not support facial recognitio...
# 24112    DISPLAY IS A LET DOWN. But the lenovo Pen work...
# Name: review, Length: 24113, dtype: object

# %%
#  df[['col1','col2']]: Select multiple columns
datacsv[['product_name', 'review']]
# Out:
#                                             product_name  \
# 0      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# ...                                                  ...
# 24108  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...
# 24109  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...
# 24110  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...
# 24111  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...
# 24112  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...
#
#                                                   review
# 0      Loved it, it's my first MacBook that I earned ...
# 1      Battery lasted longer than my first relationsh...
# 2      Such a great deal.. very happy with the perfor...
# 3      Awesome build quality and very good display, b...
# 4      When i ordered and came to know about seller r...
# ...                                                  ...
# 24108  MSI Laptop is high performance and the best. c...
# 24109                 Excellent performance best laptop.
# 24110  Decent battery life. Exceptional build quality...
# 24111  The product does not support facial recognitio...
# 24112  DISPLAY IS A LET DOWN. But the lenovo Pen work...
#
# [24113 rows x 2 columns]

# %%
# df.iloc: .iloc is used to access data by index number
# syntax: .iloc[row_index, column_index]
datacsv.iloc[4, 0]
# Out:
# 'Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey)...'

# %%
# df.loc: .loc is used to access data by label (name)
# syntax: .loc[row_label, column_label]
datacsv.loc[512, 'product_name']
# Out:
# 'SAMSUNG Galaxy Book4 Metal Intel Core i3 13th Gen 1315U - (8 G...'

# %%
# Convert String Format data in integer 
datacsv['no_ratings'] = datacsv['no_ratings'].str.replace(',', '').astype(int)

# %%
# Filter rows where no_ratings > 1500.
datacsv[datacsv['no_ratings']> 1500]
# Out:
#                                             product_name  overall_rating  \
# 0      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# ...                                                  ...             ...
# 23702  HP Victus 15 Intel Core i5 12th Gen 12450H - (...             4.3
# 23703  HP Victus 15 Intel Core i5 12th Gen 12450H - (...             4.3
# 23704  HP Victus 15 Intel Core i5 12th Gen 12450H - (...             4.3
# 23705  HP Victus 15 Intel Core i5 12th Gen 12450H - (...             4.3
# 23706  HP Victus 15 Intel Core i5 12th Gen 12450H - (...             4.3
#
#        no_ratings no_reviews  rating                   title  \
# 0           15210        900       5        Perfect product!
# 1           15210        900       5               Fabulous!
# 2           15210        900       5               Fabulous!
# 3           15210        900       4              Delightful
# 4           15210        900       5                 Awesome
# ...           ...        ...     ...                     ...
# 23702        1789        127       1  Worst experience ever!
# 23703        1789        127       4                Terrific
# 23704        1789        127       5               Excellent
# 23705        1789        127       5          Simply awesome
# 23706        1789        127       5     Best in the market!
#
#                                                   review
# 0      Loved it, it's my first MacBook that I earned ...
# 1      Battery lasted longer than my first relationsh...
# 2      Such a great deal.. very happy with the perfor...
# 3      Awesome build quality and very good display, b...
# 4      When i ordered and came to know about seller r...
# ...                                                  ...
# 23702  After 4 days of my purchase, its showing flick...
# 23703                                    Value for money
# 23704                  Awesome\nBest in this price range
# 23705                          Best laptop in this price
# 23706  The product is very good but the battery is no...
#
# [12328 rows x 7 columns]

# %%
# df.set_index('column'): Set a column as the index.
datacsv.set_index('no_ratings')
# Out:
#                                                  product_name  overall_rating  \
# no_ratings
# 15210       Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 15210       Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 15210       Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 15210       Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 15210       Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# ...                                                       ...             ...
# 156         MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 156         MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 156         MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 7           Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
# 7           Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
#
#            no_reviews  rating                          title  \
# no_ratings
# 15210             900       5               Perfect product!
# 15210             900       5                      Fabulous!
# 15210             900       5                      Fabulous!
# 15210             900       4                     Delightful
# 15210             900       5                        Awesome
# ...               ...     ...                            ...
# 156                24       5               Perfect product!
# 156                24       5               Perfect product!
# 156                24       4  Good product, Lacks features.
# 7                   2       3                           Nice
# 7                   2       4                      Very Good
#
#                                                        review
# no_ratings
# 15210       Loved it, it's my first MacBook that I earned ...
# 15210       Battery lasted longer than my first relationsh...
# 15210       Such a great deal.. very happy with the perfor...
# 15210       Awesome build quality and very good display, b...
# 15210       When i ordered and came to know about seller r...
# ...                                                       ...
# 156         MSI Laptop is high performance and the best. c...
# 156                        Excellent performance best laptop.
# 156         Decent battery life. Exceptional build quality...
# 7           The product does not support facial recognitio...
# 7           DISPLAY IS A LET DOWN. But the lenovo Pen work...
#
# [24113 rows x 6 columns]

# %%
datacsv.shape
# 24113 rows and 7 columns
# Out:
# (24113, 7)

# %%
# df.iloc[0:5, 0:2]: Slice rows and columns. (0:5 means 5 rows) (0:2 means 2 columns)
datacsv.iloc[0:10, 0:3]
# Out:
#                                         product_name  overall_rating  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 5  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 6  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 7  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 8  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 9  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
#
#    no_ratings
# 0       15210
# 1       15210
# 2       15210
# 3       15210
# 4       15210
# 5       15210
# 6       15210
# 7       15210
# 8       15210
# 9       15210
